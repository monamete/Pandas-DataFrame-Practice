# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({"Name":['Avery Bradly','John Holland','Jonas Jerebco','Jorden mickey','Terry Rozier','Jarred Sellinger','Evan Tucner'],
                    "Team":['Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics'],
                    "Number":[0.0,30.0,8.0,"nan",12.0,7.0,11.0],
                    "Position":['PG','SG','PF','PF','PG','C','SG'],
                    "Age":[25.0,27.0,29.0,21.0,22.0,"nan",27.0]})

# %%
data
# Out:
#                Name            Team Number Position   Age
# 0      Avery Bradly  Boston Celtics    0.0       PG  25.0
# 1      John Holland  Boston Celtics   30.0       SG  27.0
# 2     Jonas Jerebco  Boston Celtics    8.0       PF  29.0
# 3     Jorden mickey  Boston Celtics    NaN       PF  21.0
# 4      Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jarred Sellinger  Boston Celtics    7.0        C   NaN
# 6       Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
#total no. of elements
data.size
# Out:
# 35

# %%
#check no. of rows and columns
data.shape
# Out:
# (7, 5)

# %%
#access column names
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age'], dtype='object')

# %%
#check index
data.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
#no. of rows
data.shape[0]
# Out:
# 7

# %%
#no.of columns
data.shape[1]
# Out:
# 5

# %%
len(data)
# Out:
# 7

# %%
data['Name']
# Out:
# 0        Avery Bradly
# 1        John Holland
# 2       Jonas Jerebco
# 3       Jorden mickey
# 4        Terry Rozier
# 5    Jarred Sellinger
# 6         Evan Tucner
# Name: Name, dtype: object

# %%
data.Team
# Out:
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# 5    Boston Celtics
# 6    Boston Celtics
# Name: Team, dtype: object

# %%
data.head()
# Out:
#             Name            Team Number Position   Age
# 0   Avery Bradly  Boston Celtics    0.0       PG  25.0
# 1   John Holland  Boston Celtics   30.0       SG  27.0
# 2  Jonas Jerebco  Boston Celtics    8.0       PF  29.0
# 3  Jorden mickey  Boston Celtics    NaN       PF  21.0
# 4   Terry Rozier  Boston Celtics   12.0       PG  22.0

# %%
data.tail()
# Out:
#                Name            Team Number Position   Age
# 2     Jonas Jerebco  Boston Celtics    8.0       PF  29.0
# 3     Jorden mickey  Boston Celtics    NaN       PF  21.0
# 4      Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jarred Sellinger  Boston Celtics    7.0        C   NaN
# 6       Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
data.to_csv('f_1.csv',index=False)
data=pd.read_csv('f_1.csv')

# %%
data.Name.str.endswith('r')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# Name: Name, dtype: bool

# %%
data[data.Name.str.endswith('r')]
# Out:
#                Name            Team  Number Position   Age
# 4      Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jarred Sellinger  Boston Celtics     7.0        C   NaN
# 6       Evan Tucner  Boston Celtics    11.0       SG  27.0

# %%
data[data.Name.apply(lambda nm:nm.endswith('r'))]
# Out:
#                Name            Team  Number Position   Age
# 4      Terry Rozier  Boston Celtics    12.0       PG  22.0
# 5  Jarred Sellinger  Boston Celtics     7.0        C   NaN
# 6       Evan Tucner  Boston Celtics    11.0       SG  27.0

# %%
data.query('Position=="PG"')
# Out:
#            Name            Team Number Position   Age
# 0  Avery Bradly  Boston Celtics    0.0       PG  25.0
# 4  Terry Rozier  Boston Celtics   12.0       PG  22.0

# %%
data.query('Number=="nan"')
# Out:
#             Name            Team Number Position   Age
# 3  Jorden mickey  Boston Celtics    nan       PF  21.0

# %%
data[data.Name.apply(len)>12]
# Out:
#                Name            Team Number Position   Age
# 2     Jonas Jerebco  Boston Celtics    8.0       PF  29.0
# 3     Jorden mickey  Boston Celtics    nan       PF  21.0
# 5  Jarred Sellinger  Boston Celtics    7.0        C   nan

# %%
data[data.Name.apply(len)==13]
# Out:
#             Name            Team Number Position   Age
# 2  Jonas Jerebco  Boston Celtics    8.0       PF  29.0
# 3  Jorden mickey  Boston Celtics    nan       PF  21.0

# %%
#2.Another Example

# %%
df =pd.DataFrame({'Name':['Jack','Riti','Tom','Neelu','John','Mike'],
                  'Age':[34,30,31,32,16,17],
                  'City':['Sydney','Delhi','Mumbai','Bangalore','New York','las vegas'],
                  'Country':['Austrailia','India','India','India','US','US'],
                  'Course':['Computer science','Computer science','Computer science','Computer science','Computer science','Computer science'],
                  'Grade':['A','A','A','A','A','A']},index=['a','b','c','d','e','f'])

# %%
df
# Out:
#     Name  Age       City     Country            Course Grade
# a   Jack   34     Sydney  Austrailia  Computer science     A
# b   Riti   30      Delhi       India  Computer science     A
# c    Tom   31     Mumbai       India  Computer science     A
# d  Neelu   32  Bangalore       India  Computer science     A
# e   John   16   New York          US  Computer science     A
# f   Mike   17  las vegas          US  Computer science     A

# %%
df.shape
# Out:
# (6, 6)

# %%
df.shape[0]#no.of rows
# Out:
# 6

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Course', 'Grade'], dtype='object')

# %%
df.size
# Out:
# 36

# %%
df.ndim
# Out:
# 2

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.dtypes
# Out:
# Name       object
# Age         int64
# City       object
# Country    object
# Course     object
# Grade      object
# dtype: object

# %%
df[df.Name.str.startswith('J')]
# Out:
#    Name  Age      City     Country            Course Grade
# a  Jack   34    Sydney  Austrailia  Computer science     A
# e  John   16  New York          US  Computer science     A

# %%
df.query('Country=="India"')
# Out:
#     Name  Age       City Country            Course Grade
# b   Riti   30      Delhi   India  Computer science     A
# c    Tom   31     Mumbai   India  Computer science     A
# d  Neelu   32  Bangalore   India  Computer science     A

# %%
df[df.City.apply(len)>6]
# Out:
#     Name  Age       City Country            Course Grade
# d  Neelu   32  Bangalore   India  Computer science     A
# e   John   16   New York      US  Computer science     A
# f   Mike   17  las vegas      US  Computer science     A

# %%
min_len = df.City.apply(len).min()

# %%
min_len
# Out:
# 5

# %%
#Practice PRoblems on DataFrame
#1.Make a Pandas DataFrame with two-dimensional list

l1 =[['monika',29,'Engineer'],['sanika',26,'Doctor'],['Amit',35,'Lawyer']]
s = pd.DataFrame(l1,columns=['Name','Age','Occupation'])
s
# Out:
#      Name  Age Occupation
# 0  monika   29   Engineer
# 1  sanika   26     Doctor
# 2    Amit   35     Lawyer

# %%
# DataFrame from dict narray / lists
df ={'Type':['a','b','c'],'marks':[10,20,30]}
df =pd.DataFrame(df)
df
# Out:
#   Type  marks
# 0    a     10
# 1    b     20
# 2    c     30

# %%
#3.Write a Pandas program to create a dataframe from a dictionary and display it.
#Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}

# %%
s = pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})

# %%
s
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
"""
 2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.
Sample Python dictionary data and list labels:
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
"""

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(exam_data,index=labels)

# %%
print(df)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#4. Write a Pandas program to get the first 3 rows of a given DataFrame.Sample Python dictionary data and list labels:

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3fabd46fe8cf> in <cell line: 1>()
#       1 exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# ----> 2 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
#       3 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#       4 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
#       5 labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
#
# NameError: name 'np' is not defined

# %%
s=pd.DataFrame(exam_data,index=labels)

# %%
s
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#first 3 rows
df.iloc[:3]
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
#5. Write a Pandas program to select the 'name' and 'score' columns from the following DataFrame. Sample Python dictionary data and list labels:

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df =pd.DataFrame(exam_data,index=labels)

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
print(df[['name','score']])
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
#Select 'name' and 'score' columns in rows 1, 3, 5, 6 from the following data frame.

# %%
df.iloc[[1,3,5,6]][['name','score']]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
#select the rows where the number of attempts in the examination is greater than 2.
df[df.attempts > 2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
# Write a Pandas program to count the number of rows and columns of a DataFrame.Sample Python dictionary data and list labels:

# %%
total_rows = len(df.axes[0])
total_column = len(df.axes[1])
print('No.of rows:',total_rows)
print('No.of column:',total_column)
# Out:
# No.of rows: 10
# No.of column: 4

# %%
df[df.score.isna()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %%
# Write a Pandas program to select the rows the score is between 15 and 20 (inclusive).

# %%
df[df.score.between(15,20)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
#Write a Pandas program to select the rows where number of attempts in the examination is less than 2 and score greater than 15.

# %%
df[(df.attempts<2) & (df.score>15)]
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
#Write a Pandas program to change the score in row 'd' to 11.5.

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#Write a  Pandas program to change the score in row 'd' to 11.5.
df.loc['d', 'score'] = 11.5
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
# Write a  Pandas program to calculate the sum of the examination attempts by the students

# %%
df.attempts.sum()
# Out:
# 19

# %%
# Write a Pandas program to calculate the mean of all students' scores. Data is stored in a dataframe.

# %%
df.score.mean()
# Out:
# 13.333333333333334

# %%
#Write a Pandas program to append a new row 'k' to data frame with given values for each column. Now delete the new row and return the original DataFrame.

# %%
df.loc['k']=['monika',10,2,'yes']
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     monika   10.0         2     yes

# %%
df.drop('k')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
