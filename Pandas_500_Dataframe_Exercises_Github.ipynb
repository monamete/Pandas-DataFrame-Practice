# %%
import pandas as pd
import numpy as np

# %%
#1.Read data
df= pd.read_csv("/content/drive/MyDrive/sales_data_with_stores.csv")
df.head()
# Out:
#     store product_group  product_code  stock_qty    cost    price  \
# 0  Violet           PG2          4187        498  420.76   569.91
# 1    Rose           PG2          4195        473  545.64   712.41
# 2  Violet           PG2          4204        968  640.42   854.91
# 3   Daisy           PG2          4219        241  869.69  1034.55
# 4   Daisy           PG2          4718       1401   12.54    26.59
#
#    last_week_sales  last_month_sales
# 0               13                58
# 1               16                58
# 2               22                88
# 3               14                45
# 4               50               285

# %%
#2.Change dtypes
dtype = {"product_code":"string"}
df.dtypes
# Out:
# store                object
# product_group        object
# product_code          int64
# stock_qty             int64
# cost                float64
# price               float64
# last_week_sales       int64
# last_month_sales      int64
# dtype: object

# %%
df= pd.read_csv("/content/drive/MyDrive/sales_data_with_stores.csv",dtype={'stock_qty':'string'})
df.dtypes
# Out:
# store                       object
# product_group               object
# product_code                 int64
# stock_qty           string[python]
# cost                       float64
# price                      float64
# last_week_sales              int64
# last_month_sales             int64
# dtype: object

# %%
#Exercise 3 - usecols parameter
column = ["store",'last_month_sales','cost']
df= pd.read_csv("/content/drive/MyDrive/sales_data_with_stores.csv",usecols=column)
df.head()
# Out:
#     store    cost  last_month_sales
# 0  Violet  420.76                58
# 1    Rose  545.64                58
# 2  Violet  640.42                88
# 3   Daisy  869.69                45
# 4   Daisy   12.54               285

# %%
#df= pd.read_csv("/content/drive/MyDrive/sales_data_with_stores.csv",index_col='store')
#df.head()
# Out:
#        product_group  product_code  stock_qty    cost    price  \
# store
# Violet           PG2          4187        498  420.76   569.91
# Rose             PG2          4195        473  545.64   712.41
# Violet           PG2          4204        968  640.42   854.91
# Daisy            PG2          4219        241  869.69  1034.55
# Daisy            PG2          4718       1401   12.54    26.59
#
#         last_week_sales  last_month_sales
# store
# Violet               13                58
# Rose                 16                58
# Violet               22                88
# Daisy                14                45
# Daisy                50               285

# %%
#Read the first n rows in the file
df= pd.read_csv("/content/drive/MyDrive/sales_data_with_stores.csv",nrows=(200))
df
# Out:
#       store product_group  product_code  stock_qty    cost    price  \
# 0    Violet           PG2          4187        498  420.76   569.91
# 1      Rose           PG2          4195        473  545.64   712.41
# 2    Violet           PG2          4204        968  640.42   854.91
# 3     Daisy           PG2          4219        241  869.69  1034.55
# 4     Daisy           PG2          4718       1401   12.54    26.59
# ..      ...           ...           ...        ...     ...      ...
# 195  Violet           PG3          3557       2512   86.90   104.49
# 196   Daisy           PG3          3558        242   42.90    57.94
# 197  Violet           PG3          3562       1056   27.35    31.34
# 198  Violet           PG2          7755       1302  440.00   617.41
# 199   Daisy           PG4          3530        144   57.98   104.49
#
#      last_week_sales  last_month_sales
# 0                 13                58
# 1                 16                58
# ...

# %%
#Skip the first n rows in the file
df= pd.read_csv("/content/drive/MyDrive/sales_data_with_stores.csv",skiprows=(250))
df
# Out:
#       Daisy  PG6  3957  10090  26.92  31.34   867  2355
# 0     Daisy  PG4  2390   1474   3.87  14.24    22    95
# 1      Rose  PG4  2391    652   4.25  14.24    51   149
# 2     Daisy  PG4  2392    285   6.33  18.04    17    52
# 3     Daisy  PG4  2589    687   5.24  18.04    27    63
# 4      Rose  PG4  2591    411   5.42  18.04    30    92
# ..      ...  ...   ...    ...    ...    ...   ...   ...
# 745   Daisy  PG4  8048    415  11.99  11.39    28    60
# 746   Daisy  PG4  8050    -10   1.32   3.32    14    11
# 747  Violet  PG2   952   5388  37.71  61.74   331  1041
# 748  Violet  PG2  1307  44996  31.44  42.74  1772  6394
# 749  Violet  PG5  3018   1697   4.68  18.99    19    52
#
# [750 rows x 8 columns]

# %%
df.size
# Out:
# 6000

# %%
df = pd.read_csv('/content/drive/MyDrive/prices (1).csv')
df.head()
# Out:
#          date  product_id  price
# 0  2022-10-01      100121  10.76
# 1  2022-10-02      100121  10.73
# 2  2022-10-03      100121  15.96
# 3  2022-10-04      100121  11.50
# 4  2022-10-05      100121  16.49

# %%
df = pd.read_csv('/content/drive/MyDrive/prices (1).csv',parse_dates =["date"])
df.dtypes
# Out:
# date          datetime64[ns]
# product_id             int64
# price                float64
# dtype: object

# %%
df= pd.read_csv('/content/drive/MyDrive/sample_dataset.csv')
df
# Out:
#    col1  col2 col3  col4  col5
# 0  23.0  16.0   45    17     2
# 1  46.0  16.0   24     2    31
# 2   2.0  29.0    2    46    24
# 3   NaN   NaN   25    23     7
# 4   NaN   NaN   30    34    29
# 5   NaN  30.0    ?     5     6
# 6  35.0  37.0    ?    26    39
# 7   9.0   5.0   35    11    41
# 8  13.0  39.0   25     5    39
# 9  40.0  15.0   32    47    24

# %%
df= pd.read_csv('/content/drive/MyDrive/sample_dataset.csv',na_values=['?'])

# %%
df.describe()
# Out:
#              3957         10090        26.92        31.34          867  \
# count   750.00000  7.500000e+02   750.000000   750.000000   750.000000
# mean   5127.96000  7.430539e+03    46.098053    68.180080    77.368000
# std    2876.24348  1.498583e+05   112.790589   145.061712   206.853342
# min      16.00000 -1.230000e+02     0.540000     0.660000    12.000000
# 25%    2650.25000  4.730000e+02     6.710000    14.240000    18.000000
# 50%    4935.50000  1.057000e+03    13.565000    25.640000    31.000000
# 75%    7919.75000  2.142750e+03    34.447500    56.990000    65.000000
# max    9972.00000  4.104542e+06  1243.000000  1500.050000  3222.000000
#
#                2355
# count    750.000000
# mean     280.536000
# std      772.946403
# min       11.000000
# 25%       60.000000
# 50%      110.000000
# 75%      236.750000
# max    12353.000000

# %%
#Exercise 8 - describe function
df.describe(include=[object])
# Out:
#         Daisy  PG6
# count     750  750
# unique      3    6
# top     Daisy  PG4
# freq      360  251

# %%
#Exercise 11 - memory usage
df.memory_usage()
# Out:
# Index     128
# Daisy    6000
# PG6      6000
# 3957     6000
# 10090    6000
# 26.92    6000
# 31.34    6000
# 867      6000
# 2355     6000
# dtype: int64

# %%
df.memory_usage().sum()
# Out:
# 48128

# %%
df = pd.read_csv("/content/drive/MyDrive/apple_google_stock_prices_092022.csv")
df.head()
# Out:
#          Date        High         Low        Open       Close    Volume  \
# 0  2022-09-01  158.419998  154.669998  156.639999  157.960007  74229900
# 1  2022-09-02  160.360001  154.970001  159.750000  155.809998  76905200
# 2  2022-09-06  157.089996  153.690002  156.470001  154.529999  73714800
# 3  2022-09-07  156.669998  153.610001  154.820007  155.960007  87449600
# 4  2022-09-08  156.360001  152.679993  154.639999  154.460007  84923800
#
#     Adj Close Stock
# 0  157.960007  AAPL
# 1  155.809998  AAPL
# 2  154.529999  AAPL
# 3  155.960007  AAPL
# 4  154.460007  AAPL

# %%
df.dtypes
# Out:
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume         int64
# Adj Close    float64
# Stock         object
# dtype: object

# %%
#Exercise 10 - dtype method
df['Close'].dtypes
# Out:
# dtype('float64')

# %%
df[["Volume",'Low']].dtypes
# Out:
# Volume      int64
# Low       float64
# dtype: object

# %%
#Exercise 11 - astype function= used for changing the datatypes of columns
df["Volume"] = df["Volume"].astype("float32")
df.dtypes
# Out:
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float32
# Adj Close    float64
# Stock         object
# dtype: object

# %%
#changing the datatypes of multiple columns
df=df.astype({"Volume":"int32","Stock":"string"})
df[["Volume","Stock"]].dtypes
# Out:
# Volume             int32
# Stock     string[python]
# dtype: object

# %%
#Exercise 12 - select_dtypes function
df.select_dtypes(include="float64").head()
# Out:
#          High         Low        Open       Close   Adj Close
# 0  158.419998  154.669998  156.639999  157.960007  157.960007
# 1  160.360001  154.970001  159.750000  155.809998  155.809998
# 2  157.089996  153.690002  156.470001  154.529999  154.529999
# 3  156.669998  153.610001  154.820007  155.960007  155.960007
# 4  156.360001  152.679993  154.639999  154.460007  154.460007

# %%
df.select_dtypes(exclude="float64").head()
# Out:
#          Date    Volume Stock
# 0  2022-09-01  74229904  AAPL
# 1  2022-09-02  76905200  AAPL
# 2  2022-09-06  73714800  AAPL
# 3  2022-09-07  87449600  AAPL
# 4  2022-09-08  84923800  AAPL

# %%
#Exercise 14 - categorical data
Flowers = pd.Series(['Orchid','rose','jasmine','lotus'],dtype='category')
Flowers
# Out:
# 0     Orchid
# 1       rose
# 2    jasmine
# 3      lotus
# dtype: category
# Categories (4, object): ['Orchid', 'jasmine', 'lotus', 'rose']

# %%
pd.Categorical(['Orchid','rose','jasmine','lotus'])
# Out:
# ['Orchid', 'rose', 'jasmine', 'lotus']
# Categories (4, object): ['Orchid', 'jasmine', 'lotus', 'rose']

# %%
import numpy as np
Flowers=pd.DataFrame({'F_name':pd.Categorical(['Orchid','rose','jasmine','lotus']*10,categories=['Orchid','rose','jasmine','lotus']),
                                               'Plant_count': np.random.randint(100,300,40)})
Flowers.head()
# Out:
#     F_name  Plant_count
# 0   Orchid          157
# 1     rose          262
# 2  jasmine          235
# 3    lotus          117
# 4   Orchid          157

# %%
Flowers['F_name'].value_counts()
# Out:
# F_name
# Orchid     10
# rose       10
# jasmine    10
# lotus      10
# Name: count, dtype: int64

# %%
#Flowers.iloc[0,0] = 'violet'
#Flowers['F_names'].value_counts()
Flowers["F_name"] = Flowers["F_name"].cat.add_categories('hibiscus')
Flowers['F_name'].value_counts()
# Out:
# F_name
# Orchid      10
# rose        10
# jasmine     10
# lotus       10
# violet       0
# hibiscus     0
# Name: count, dtype: int64

# %%
#Ceating columns and doing operations over it
#Creating new columns
#Dropping the existing columns
#Renaming the columns
df = pd.DataFrame({'date':pd.date_range(start='12/04/2024',periods=5,freq='D'),
                   'price':[25,36,85,56,45],
                   'sales_qty' :[10,15,12,18,17]
                   })
df
# Out:
#         date  price  sales_qty
# 0 2024-12-04     25         10
# 1 2024-12-05     36         15
# 2 2024-12-06     85         12
# 3 2024-12-07     56         18
# 4 2024-12-08     45         17

# %%
#creating a column
df['product_id'] = '201'

# %%
df
# Out:
#         date  price  sales_qty product_id
# 0 2024-12-04     25         10        201
# 1 2024-12-05     36         15        201
# 2 2024-12-06     85         12        201
# 3 2024-12-07     56         18        201
# 4 2024-12-08     45         17        201

# %%
#creating column having diff values
df['category'] = ['A','B','C','D','E']

# %%
df
# Out:
#         date  price  sales_qty product_id category
# 0 2024-12-04     25         10        201        A
# 1 2024-12-05     36         15        201        B
# 2 2024-12-06     85         12        201        C
# 3 2024-12-07     56         18        201        D
# 4 2024-12-08     45         17        201        E

# %%
#3.creating columns using random values
df['stock'] = np.random.randint(200,300,5)
df
# Out:
#         date  price  sales_qty product_id category  stock
# 0 2024-12-04     25         10        201        A    257
# 1 2024-12-05     36         15        201        B    206
# 2 2024-12-06     85         12        201        C    244
# 3 2024-12-07     56         18        201        D    200
# 4 2024-12-08     45         17        201        E    237

# %%
#4.create column using arithmatic operation
df['revenue'] = df['price'] * df['sales_qty']
df
# Out:
#         date  price  sales_qty product_id category  stock  revenue
# 0 2024-12-04     25         10        201        A    257      250
# 1 2024-12-05     36         15        201        B    206      540
# 2 2024-12-06     85         12        201        C    244     1020
# 3 2024-12-07     56         18        201        D    200     1008
# 4 2024-12-08     45         17        201        E    237      765

# %%
#5.creating multiple column
df[["A","B"]] = np.random.randint(10, size=(5, 2))
df
# Out:
#         date  price  sales_qty product_id category  stock  revenue  A  B
# 0 2024-12-04     25         10        201        A    257      250  6  9
# 1 2024-12-05     36         15        201        B    206      540  6  6
# 2 2024-12-06     85         12        201        C    244     1020  6  3
# 3 2024-12-07     56         18        201        D    200     1008  7  7
# 4 2024-12-08     45         17        201        E    237      765  2  3

# %%
#Dropping a column
df.drop('B', axis=1)
df
# Out:
#         date  price  sales_qty product_id category  stock  revenue  B
# 0 2024-12-04     25         10        201        A    257      250  9
# 1 2024-12-05     36         15        201        B    206      540  6
# 2 2024-12-06     85         12        201        C    244     1020  3
# 3 2024-12-07     56         18        201        D    200     1008  7
# 4 2024-12-08     45         17        201        E    237      765  3

# %%
#df.drop("A", axis=1, inplace=True)
df
# Out:
#         date  price  sales_qty product_id category  stock  revenue
# 0 2024-12-04     25         10        201        A    257      250
# 1 2024-12-05     36         15        201        B    206      540
# 2 2024-12-06     85         12        201        C    244     1020
# 3 2024-12-07     56         18        201        D    200     1008
# 4 2024-12-08     45         17        201        E    237      765

# %%
#change column order
new = ['date','price','stock','product_id','sales_qty','category','revenue']
df=df[new]
df
# Out:
#         date  price  stock product_id  sales_qty category  revenue
# 0 2024-12-04     25    257        201         10        A      250
# 1 2024-12-05     36    206        201         15        B      540
# 2 2024-12-06     85    244        201         12        C     1020
# 3 2024-12-07     56    200        201         18        D     1008
# 4 2024-12-08     45    237        201         17        E      765

# %%
#insert function
df.insert(2, "C", 101)
df
# Out:
#         date  price    C    A  stock product_id  sales_qty category  revenue
# 0 2024-12-04     25  101  101    257        201         10        A      250
# 1 2024-12-05     36  101  101    206        201         15        B      540
# 2 2024-12-06     85  101  101    244        201         12        C     1020
# 3 2024-12-07     56  101  101    200        201         18        D     1008
# 4 2024-12-08     45  101  101    237        201         17        E      765

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d3bc7fac738e> in <cell line: 2>()
#       1 #check first 5 entries
# ----> 2 df.head()
#
# NameError: name 'df' is not defined
